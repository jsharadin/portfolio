# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.cluster import KMeans
import quantecon as qe
import matplotlib.pyplot as plt
import pickle
import kagglehub
from linearmodels.iv import IVGMM
from linearmodels.iv import IV2SLS

# %% [markdown]
# ***Load in Data***

# %%
# 2010 population + crime data
with open('df_2010_controls2_final.pkl', 'rb') as f:
    df_2010_controls2_final = pickle.load(f)

# Create a copy
df_2010_copy = df_2010_controls2_final.copy()
df_2010_copy.head()
# Out:
#    county  schedule1_count  schedule2_count  total_pop_1860  log_slave  \
# 0    10.0         360232.0           3475.0        363707.0   8.153350
# 1    30.0         292363.0           1537.0        293900.0   7.337588
# 2    50.0         395136.0           1872.0        397008.0   7.534763
# 3    70.0         136102.0           2639.0        138741.0   7.878155
# 4    90.0         375103.0           1078.0        376181.0   6.982863
#
#     ag_output  ag_gdp_1860   gini_x  cash_value_farms    state  ... gdp_2014  \
# 0  32662909.0    89.805557  0.54031       129368094.0  Alabama  ...  1569120
# 1  27996221.0    95.257645  0.58392       152052217.0  Alabama  ...  6034727
# 2  31948684.0    80.473656  0.52155       142857209.0  Alabama  ...   779299
# 3  24998235.0   180.179153  0.43734        99711086.0  Alabama  ...   381354
# 4  21747586.0    57.811497  0.59723        88331569.0  Alabama  ...   928552
#
#    gdp_2015  gdp_2016 gdp_2017 gdp_2018  gdp_2019 gdp_2020 gdp_2021  gdp_2022  \
# 0   1729098   1806246  1762558  1826642   1814228  1841867  1954645   2318914
# 1   6492574   6983037  7382558  7935575   8558537  8770138  9847424  11097699
# 2    765000    757473   761761   789103    793769   787697   868828    931174
# 3    377535    392287   406741   408791    465977   502089   530401    571231
# 4    987510    925988   987967  1064218   1055980   973485  1162103   1266269
#
#    gdp_2023
# 0   2452642
# 1  12071468
# 2    926685
# 3    610429
# 4   1261107
#
# [5 rows x 154 columns]

# %% [markdown]
# ***Murder rate 2nd stage OLS with 0,1,2,3 controls***

# %%
# Define the dependent variable (outcome of the first stage)
y = df_2010_copy['log_murder_rate']  # Replace 'dependent_var' with the actual name of your dependent variable

# 2nd Stage with No Controls
X0 = df_2010_copy[['gini_stata']]  # Replace with the main independent variable for the first stage
X0 = sm.add_constant(X0)  # Adds an intercept to the model
model0 = sm.OLS(y, X0).fit()
print("First Stage OLS with 0 Controls")
print(model0.summary())

# 2nd Stage with 1 Control
X1 = df_2010_copy[['gini_stata', 'pop_density_2010']]  # Replace 'control_var1' with the name of your control variable
X1 = sm.add_constant(X1)
model1 = sm.OLS(y, X1).fit()
print("\nFirst Stage OLS with 1 Control")
print(model1.summary())

# 2nd Stage with 2 Controls
X2 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010']]  # Add a second control variable
X2 = sm.add_constant(X2)
model2 = sm.OLS(y, X2).fit()
print("\nFirst Stage OLS with 2 Controls")
print(model2.summary())

# 2nd Stage with 3 Controls
X3 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010', 'gdp_2010']]  # Add a third control variable
X3 = sm.add_constant(X3)
model3 = sm.OLS(y, X3).fit()
print("\nFirst Stage OLS with 3 Controls")
print(model3.summary())
# Out:
# First Stage OLS with 0 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_murder_rate   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     4.137
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):             0.0441
# Time:                        11:39:16   Log-Likelihood:                -174.62
# No. Observations:                 126   AIC:                             353.2
# Df Residuals:                     124   BIC:                             358.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5193      0.296      1.754      0.082      -0.067       1.105
# gini_stata     1.2282      0.604      2.034      0.044       0.033       2.424
# ==============================================================================
# Omnibus:                       15.573   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                6.167
# Skew:                           0.280   Prob(JB):                       0.0458
# Kurtosis:                       2.072   Cond. No.                         8.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# First Stage OLS with 1 Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_murder_rate   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.052
# Method:                 Least Squares   F-statistic:                     4.435
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):             0.0138
# Time:                        11:39:16   Log-Likelihood:                -172.30
# No. Observations:                 126   AIC:                             350.6
# Df Residuals:                     123   BIC:                             359.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.3858      0.298      1.293      0.199      -0.205       0.976
# gini_stata           1.2870      0.596      2.160      0.033       0.107       2.467
# pop_density_2010     0.0009      0.000      2.148      0.034    6.79e-05       0.002
# ==============================================================================
# Omnibus:                       13.824   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                6.081
# Skew:                           0.301   Prob(JB):                       0.0478
# Kurtosis:                       2.109   Cond. No.                     1.89e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 2 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_murder_rate   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     3.094
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):             0.0295
# Time:                        11:39:16   Log-Likelihood:                -172.07
# No. Observations:                 126   AIC:                             352.1
# Df Residuals:                     122   BIC:                             363.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.3580      0.302      1.186      0.238      -0.240       0.956
# gini_stata                 1.3693      0.610      2.246      0.027       0.162       2.576
# pop_density_2010           0.0013      0.001      1.720      0.088      -0.000       0.003
# total_males_15_29_2010 -9.129e-06   1.36e-05     -0.672      0.503    -3.6e-05    1.77e-05
# ==============================================================================
# Omnibus:                       13.648   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.727
# Skew:                           0.268   Prob(JB):                       0.0571
# Kurtosis:                       2.104   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 3 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_murder_rate   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.040
# Method:                 Least Squares   F-statistic:                     2.306
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):             0.0621
# Time:                        11:39:16   Log-Likelihood:                -172.06
# No. Observations:                 126   AIC:                             354.1
# Df Residuals:                     121   BIC:                             368.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.3529      0.306      1.154      0.251      -0.253       0.958
# gini_stata                 1.3696      0.612      2.237      0.027       0.158       2.581
# pop_density_2010           0.0013      0.001      1.600      0.112      -0.000       0.003
# total_males_15_29_2010 -4.553e-06   3.91e-05     -0.117      0.907   -8.19e-05    7.28e-05
# gdp_2010               -9.497e-09    7.6e-08     -0.125      0.901    -1.6e-07    1.41e-07
# ==============================================================================
# Omnibus:                       13.533   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.743
# Skew:                           0.272   Prob(JB):                       0.0566
# Kurtosis:                       2.107   Cond. No.                     4.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(X3.dtypes)
# Out:
# const                     float64
# gini_stata                float32
# pop_density_2010          float64
# total_males_15_29_2010      int64
# gdp_2010                   object
# dtype: object

# %% [markdown]
# ***Vehicle theft rate 2nd stage OLS with 0,1,2, controls***

# %%
# Define the dependent variable (outcome of the first stage)
y = df_2010_copy['log_mtv_theft_rate']  # Replace 'dependent_var' with the actual name of your dependent variable

# 2nd Stage with No Controls
X0 = df_2010_copy[['gini_stata']]  # Replace with the main independent variable for the first stage
X0 = sm.add_constant(X0)  # Adds an intercept to the model
model0 = sm.OLS(y, X0).fit()
print("First Stage OLS with 0 Controls")
print(model0.summary())

# 2nd Stage with 1 Control
X1 = df_2010_copy[['gini_stata', 'pop_density_2010']]  # Replace 'control_var1' with the name of your control variable
X1 = sm.add_constant(X1)
model1 = sm.OLS(y, X1).fit()
print("\nFirst Stage OLS with 1 Control")
print(model1.summary())

# 2nd Stage with 2 Controls
X2 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010']]  # Add a second control variable
X2 = sm.add_constant(X2)
model2 = sm.OLS(y, X2).fit()
print("\nFirst Stage OLS with 2 Controls")
print(model2.summary())

# 2nd Stage with 3 Controls
X3 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010', 'gdp_2010']]  # Add a third control variable
X3 = sm.add_constant(X3)
model3 = sm.OLS(y, X3).fit()
print("\nFirst Stage OLS with 3 Controls")
print(model3.summary())
# Out:
# First Stage OLS with 0 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     log_mtv_theft_rate   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                   0.01557
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.901
# Time:                        11:42:25   Log-Likelihood:                -184.14
# No. Observations:                 126   AIC:                             372.3
# Df Residuals:                     124   BIC:                             377.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6936      0.319      8.435      0.000       2.062       3.326
# gini_stata     0.0813      0.651      0.125      0.901      -1.208       1.370
# ==============================================================================
# Omnibus:                       32.615   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.326
# Skew:                          -1.293   Prob(JB):                     1.95e-11
# Kurtosis:                       4.645   Cond. No.                         8.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# First Stage OLS with 1 Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     log_mtv_theft_rate   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.5788
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.562
# Time:                        11:42:25   Log-Likelihood:                -183.56
# No. Observations:                 126   AIC:                             373.1
# Df Residuals:                     123   BIC:                             381.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.6210      0.326      8.032      0.000       1.975       3.267
# gini_stata           0.1132      0.652      0.174      0.862      -1.176       1.403
# pop_density_2010     0.0005      0.000      1.069      0.287      -0.000       0.001
# ==============================================================================
# Omnibus:                       31.134   Durbin-Watson:                   2.171
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.567
# Skew:                          -1.264   Prob(JB):                     1.27e-10
# Kurtosis:                       4.513   Cond. No.                     1.89e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 2 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     log_mtv_theft_rate   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.8820
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.453
# Time:                        11:42:25   Log-Likelihood:                -182.79
# No. Observations:                 126   AIC:                             373.6
# Df Residuals:                     122   BIC:                             384.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      2.5662      0.329      7.805      0.000       1.915       3.217
# gini_stata                 0.2756      0.664      0.415      0.679      -1.039       1.590
# pop_density_2010           0.0013      0.001      1.603      0.112      -0.000       0.003
# total_males_15_29_2010 -1.801e-05   1.48e-05     -1.218      0.226   -4.73e-05    1.13e-05
# ==============================================================================
# Omnibus:                       33.212   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.838
# Skew:                          -1.307   Prob(JB):                     9.13e-12
# Kurtosis:                       4.690   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 3 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     log_mtv_theft_rate   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.6564
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.623
# Time:                        11:42:25   Log-Likelihood:                -182.79
# No. Observations:                 126   AIC:                             375.6
# Df Residuals:                     121   BIC:                             389.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      2.5647      0.333      7.702      0.000       1.905       3.224
# gini_stata                 0.2756      0.667      0.414      0.680      -1.044       1.595
# pop_density_2010           0.0013      0.001      1.516      0.132      -0.000       0.003
# total_males_15_29_2010 -1.667e-05   4.25e-05     -0.392      0.696      -0.000    6.75e-05
# gdp_2010               -2.775e-09   8.27e-08     -0.034      0.973   -1.67e-07    1.61e-07
# ==============================================================================
# Omnibus:                       33.170   Durbin-Watson:                   2.169
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.738
# Skew:                          -1.305   Prob(JB):                     9.60e-12
# Kurtosis:                       4.687   Cond. No.                     4.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ***Crime rate 2nd stage OLS with 0,1,2,3 controls***

# %%
# Define the dependent variable (outcome of the first stage)
y = df_2010_copy['log_crime_rate']  # Replace 'dependent_var' with the actual name of your dependent variable

# 2nd Stage with No Controls
X0 = df_2010_copy[['gini_stata']]  # Replace with the main independent variable for the first stage
X0 = sm.add_constant(X0)  # Adds an intercept to the model
model0 = sm.OLS(y, X0).fit()
print("First Stage OLS with 0 Controls")
print(model0.summary())

# 2nd Stage with 1 Control
X1 = df_2010_copy[['gini_stata', 'pop_density_2010']]  # Replace 'control_var1' with the name of your control variable
X1 = sm.add_constant(X1)
model1 = sm.OLS(y, X1).fit()
print("\nFirst Stage OLS with 1 Control")
print(model1.summary())

# 2nd Stage with 2 Controls
X2 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010']]  # Add a second control variable
X2 = sm.add_constant(X2)
model2 = sm.OLS(y, X2).fit()
print("\nFirst Stage OLS with 2 Controls")
print(model2.summary())

# 2nd Stage with 3 Controls
X3 = df_2010_copy[['gini_stata', 'pop_density_2010', 'total_males_15_29_2010', 'gdp_2010']]  # Add a third control variable
X3 = sm.add_constant(X3)
model3 = sm.OLS(y, X3).fit()
print("\nFirst Stage OLS with 3 Controls")
print(model3.summary())
# Out:
# First Stage OLS with 0 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         log_crime_rate   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                  0.007254
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.932
# Time:                        11:47:05   Log-Likelihood:                -109.70
# No. Observations:                 126   AIC:                             223.4
# Df Residuals:                     124   BIC:                             229.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.1738      0.177     46.212      0.000       7.824       8.524
# gini_stata    -0.0307      0.361     -0.085      0.932      -0.745       0.683
# ==============================================================================
# Omnibus:                       33.964   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.558
# Skew:                          -1.129   Prob(JB):                     7.86e-16
# Kurtosis:                       5.855   Cond. No.                         8.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# First Stage OLS with 1 Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         log_crime_rate   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                   0.06414
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.938
# Time:                        11:47:05   Log-Likelihood:                -109.64
# No. Observations:                 126   AIC:                             225.3
# Df Residuals:                     123   BIC:                             233.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                8.1870      0.181     45.110      0.000       7.828       8.546
# gini_stata          -0.0365      0.362     -0.101      0.920      -0.754       0.681
# pop_density_2010 -8.547e-05      0.000     -0.348      0.728      -0.001       0.000
# ==============================================================================
# Omnibus:                       33.178   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.231
# Skew:                          -1.107   Prob(JB):                     2.52e-15
# Kurtosis:                       5.812   Cond. No.                     1.89e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 2 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         log_crime_rate   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.281
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.284
# Time:                        11:47:05   Log-Likelihood:                -107.75
# No. Observations:                 126   AIC:                             223.5
# Df Residuals:                     122   BIC:                             234.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.1392      0.181     44.912      0.000       7.780       8.498
# gini_stata                 0.1050      0.366      0.287      0.775      -0.619       0.829
# pop_density_2010           0.0006      0.000      1.434      0.154      -0.000       0.002
# total_males_15_29_2010  -1.57e-05   8.15e-06     -1.926      0.056   -3.18e-05    4.33e-07
# ==============================================================================
# Omnibus:                       30.084   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.600
# Skew:                          -1.046   Prob(JB):                     8.44e-13
# Kurtosis:                       5.492   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 3 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         log_crime_rate   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.377
# Date:                Mon, 09 Dec 2024   Prob (F-statistic):              0.246
# Time:                        11:47:05   Log-Likelihood:                -106.90
# No. Observations:                 126   AIC:                             223.8
# Df Residuals:                     121   BIC:                             238.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      8.1085      0.182     44.471      0.000       7.747       8.469
# gini_stata                 0.1069      0.365      0.293      0.770      -0.616       0.829
# pop_density_2010           0.0005      0.000      0.996      0.321      -0.000       0.001
# total_males_15_29_2010  1.228e-05   2.33e-05      0.528      0.599   -3.38e-05    5.84e-05
# gdp_2010               -5.808e-08   4.53e-08     -1.282      0.202   -1.48e-07    3.16e-08
# ==============================================================================
# Omnibus:                       28.889   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.077
# Skew:                          -1.007   Prob(JB):                     2.98e-12
# Kurtosis:                       5.460   Cond. No.                     4.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ***1st stage OLS with 0,1,2 controls***

# %%
# Define the dependent variable (outcome of the first stage)
y = df_2010_copy['gini_stata']  # Replace 'dependent_var' with the actual name of your dependent variable

# 2nd Stage with No Controls
X0 = df_2010_copy[['log_slave']]  # Replace with the main independent variable for the first stage
X0 = sm.add_constant(X0)  # Adds an intercept to the model
model0 = sm.OLS(y, X0).fit()
print("First Stage OLS with 0 Controls")
print(model0.summary())

# 2nd Stage with 1 Control
X1 = df_2010_copy[['log_slave', 'pop_density_2010']]  # Replace 'control_var1' with the name of your control variable
X1 = sm.add_constant(X1)
model1 = sm.OLS(y, X1).fit()
print("\nFirst Stage OLS with 1 Control")
print(model1.summary())

# 2nd Stage with 2 Controls
X2 = df_2010_copy[['log_slave', 'pop_density_2010', 'total_males_15_29_2010']]  # Add a second control variable
X2 = sm.add_constant(X2)
model2 = sm.OLS(y, X2).fit()
print("\nFirst Stage OLS with 2 Controls")
print(model2.summary())
# Out:
# First Stage OLS with 0 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gini_stata   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.312
# Method:                 Least Squares   F-statistic:                     61.69
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.19e-12
# Time:                        19:36:37   Log-Likelihood:                 95.840
# No. Observations:                 135   AIC:                            -187.7
# Df Residuals:                     133   BIC:                            -181.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.061      0.005      0.996      -0.120       0.120
# log_slave      0.0695      0.009      7.855      0.000       0.052       0.087
# ==============================================================================
# Omnibus:                       10.392   Durbin-Watson:                   1.556
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.498
# Skew:                          -0.624   Prob(JB):                      0.00525
# Kurtosis:                       3.557   Cond. No.                         41.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# First Stage OLS with 1 Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gini_stata   R-squared:                       0.317
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     30.65
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           1.17e-11
# Time:                        19:36:37   Log-Likelihood:                 95.862
# No. Observations:                 135   AIC:                            -185.7
# Df Residuals:                     132   BIC:                            -177.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.0016      0.061      0.026      0.979      -0.120       0.123
# log_slave            0.0695      0.009      7.826      0.000       0.052       0.087
# pop_density_2010 -9.765e-06   4.73e-05     -0.207      0.837      -0.000    8.37e-05
# ==============================================================================
# Omnibus:                       10.540   Durbin-Watson:                   1.557
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               10.676
# Skew:                          -0.630   Prob(JB):                      0.00481
# Kurtosis:                       3.558   Cond. No.                     1.52e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# First Stage OLS with 2 Controls
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gini_stata   R-squared:                       0.326
# Model:                            OLS   Adj. R-squared:                  0.311
# Method:                 Least Squares   F-statistic:                     21.12
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           3.20e-11
# Time:                        19:36:37   Log-Likelihood:                 96.744
# No. Observations:                 135   AIC:                            -185.5
# Df Residuals:                     131   BIC:                            -173.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      0.0191      0.063      0.306      0.760      -0.105       0.143
# log_slave                  0.0665      0.009      7.275      0.000       0.048       0.085
# pop_density_2010       -9.901e-05   8.27e-05     -1.197      0.234      -0.000    6.47e-05
# total_males_15_29_2010  1.808e-06   1.38e-06      1.312      0.192   -9.17e-07    4.53e-06
# ==============================================================================
# Omnibus:                       10.256   Durbin-Watson:                   1.577
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.349
# Skew:                          -0.614   Prob(JB):                      0.00566
# Kurtosis:                       3.575   Cond. No.                     9.41e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.41e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
